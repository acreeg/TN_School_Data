# %%
import pandas as pd
filename = '/Users/glennacree/Dropbox/DataScience/SchoolData/data_2015_school_profile.csv'
data = pd.read_csv(filename)

# %%
data
# Out:
#       YEAR  DISTRICT                DISTRICT_NAME  \
# 0     2015       920               Weakley County
# 1     2015       330              Hamilton County
# 2     2015       330              Hamilton County
# 3     2015       792                Shelby County
# 4     2015       985  Achievement School District
# 5     2015       792                Shelby County
# 6     2015       985  Achievement School District
# 7     2015       985  Achievement School District
# 8     2015       792                Shelby County
# 9     2015       985  Achievement School District
# 10    2015       271                     Humboldt
# 11    2015       792                Shelby County
# 12    2015       350              Hardeman County
# 13    2015       330              Hamilton County
# 14    2015       985  Achievement School District
# 15    2015       792                Shelby County
# 16    2015       792                Shelby County
# 17    2015       985  Achievement School District
# ...

# %%
import matplotlib.pyplot as plt

#data.ECONOMICALLY_DISADVANTAGED_PCT.plot.bar()

# %%
#data2 = data.fillna(value=1.0)
#data2.plot.scatter(x ='ECONOMICALLY_DISADVANTAGED_PCT', y ='WHITE_PCT');
#plt.show()

# %%
# %pylab
africanAmerdata = array(data.AFRICAN_AMERICAN_PCT)
econDisdata = array(data.ECONOMICALLY_DISADVANTAGED_PCT)
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
isnan(africanAmerdata)
# Out:
# array([False, False, False, ..., False, False,  True], dtype=bool)

# %%
len(africanAmerdata)
# Out:
# 1958

# %%
len(data)
# Out:
# 1958

# %%
econDis_africanAmer = array([[econDisdata],[africanAmerdata]])

# %%
econDisdata
# Out:
# array([ 100. ,   99.8,   99.8, ...,    nan,    nan,    nan])

# %%
plt.scatter(econDisdata,africanAmerdata)
plt.show()
