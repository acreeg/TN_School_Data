# %%
import pandas as pd
filename = '/Users/glennacree/Dropbox/DataScience/SchoolData/data_2015_district_profile.csv'
data = pd.read_csv(filename)

# %%
data
# Out:
#      YEAR  DISTRICT                DISTRICT_NAME GRADES_SERVED  \
# 0    2015        10              Anderson County         PK-12
# 1    2015        11                      Clinton          PK-6
# 2    2015        12                    Oak Ridge          K-12
# 3    2015        20               Bedford County         PK-12
# 4    2015        30                Benton County         PK-12
# 5    2015        40               Bledsoe County         PK-12
# 6    2015        50                Blount County         PK-12
# 7    2015        51                        Alcoa         PK-12
# 8    2015        52                    Maryville         PK-12
# 9    2015        60               Bradley County         PK-12
# 10   2015        61                    Cleveland         PK-12
# 11   2015        70              Campbell County         PK-12
# 12   2015        80                Cannon County         PK-12
# 13   2015        90               Carroll County         PK-12
# ...

# %%
#import numpy as np
import matplotlib.pyplot as plt
#import matplotlib

data.ECONOMICALLY_DISADVANTAGED_PCT.plot.bar()
plt.show()

# %%
data.plot.scatter(x = 'ECONOMICALLY_DISADVANTAGED_PCT', y = 'FEDERAL_FUNDING_PCT')
plt.show()
